# %%
import requests
import pandas as pd
import streamlit as st

#下載youbike資料
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
response = requests.request('GET',url)
if response.status_code == 200:
    print("連線成功")
    all_data = response.json()
    print(type(all_data))
else:
    print(f"連線失敗:{response.status_code}")
# Out:
# 連線成功
# <class 'list'>

# %%
#將youbike資料轉成dataFrame
dataFrame = pd.DataFrame(data=all_data,columns=['sna','tot','sbi','sarea','mday','ar','bemp','act'])
dataFrame
# Out:
#                            sna  tot  sbi   sarea                 mday  \
# 0           YouBike2.0_捷運科技大樓站   28    8     大安區  2023-06-10 11:54:19
# 1       YouBike2.0_復興南路二段273號前   21    7     大安區  2023-06-10 11:40:24
# 2         YouBike2.0_國北教大實小東側門   16    4     大安區  2023-06-10 11:38:14
# 3            YouBike2.0_和平公園東側   11    2     大安區  2023-06-10 11:44:15
# 4         YouBike2.0_辛亥復興路口西北側   16   16     大安區  2023-06-10 11:49:04
# ...                        ...  ...  ...     ...                  ...
# 1276      YouBike2.0_臺大總圖書館西南側   30   15    臺大專區  2023-06-10 11:53:17
# 1277        YouBike2.0_臺大黑森林西側   20    5    臺大專區  2023-06-10 11:48:17
# 1278        YouBike2.0_臺大獸醫館南側   24    1    臺大專區  2023-06-10 11:39:04
# 1279      YouBike2.0_臺大新體育館東南側   40   15    臺大專區  2023-06-10 11:47:18
# 1280  YouBike2.0_臺大明達館北側(員工宿舍)   18    0  臺大公館校區  2023-06-10 10:00:44
#
#                  ar  bemp act
# 0       復興南路二段235號前    20   1
# 1      復興南路二段273號西側    14   1
# 2       和平東路二段96巷7號    12   1
# 3     和平東路二段118巷33號     9   1
# 4        復興南路二段368號     0   1
# ...             ...   ...  ..
# 1276       臺大圖書館西南側    15   1
# 1277        臺大霖澤館南側    15   1
# 1278       臺大獸醫系館南側    23   1
# 1279        臺大體育館東側    15   1
# 1280       明達館北側前空地    18   1
#
# [1281 rows x 8 columns]

# %%
dataFrame1['行政區'].drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dataFrame1['行政區'].drop_duplicates()
#
# NameError: name 'dataFrame1' is not defined
